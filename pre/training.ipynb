# %%
import pandas as pd

df = pd.read_csv('processed/weekly/combined.csv')
df.info()
df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         442 non-null    int64
#  1   Week                         442 non-null    int64
#  2   food_item                    442 non-null    str
#  3   State                        442 non-null    str
#  4   price                        442 non-null    float64
#  5   item_type                    442 non-null    str
#  6   category                     442 non-null    str
#  7   Precipitation_mm             442 non-null    float64
#  8   Avg_Temperature_C            442 non-null    float64
#  9   Solar_Radiation_MJ           442 non-null    float64
#  10  Weekly_Econ_Sentiment_Score  429 non-null    float64
#  11  Events                       442 non-null    float64
#  12  Fatalities                   442 non-null    float64
# ...

# %%
df.State.unique()
# Out:
# <StringArray>
# ['Lagos']
# Length: 1, dtype: str
